# %%
import pandas as pd
from pathlib import Path

# %%
data_file = Path("Resources", "data", "data.csv")

covid_df = pd.read_csv(data_file)
covid_df.sample(10)
# Out:
#                Entity      Continent  Latitude  Longitude  \
# 37293         Uruguay  South America    -32.52     -55.77
# 11955          Greece         Europe     39.07      21.82
# 6356         Colombia  South America      4.57     -74.30
# 33492        Thailand           Asia     15.87     100.99
# 14460            Iraq           Asia     33.22      43.68
# 38195        Zimbabwe         Africa    -19.02      29.15
# 31939     South Korea           Asia     35.91     127.77
# 36580  United Kingdom         Europe     55.38      -3.44
# 8199          Denmark         Europe     56.26       9.50
# 31431    South Africa         Africa    -30.56      22.94
#
#        Average temperature per year  Hospital beds per 1000 people  \
# 37293                            16                           2.80
# 11955                            17                           4.21
# 6356                             25                           1.71
# ...

# %%
covid_df.columns
# Out:
# Index(['Entity', 'Continent', 'Latitude', 'Longitude',
#        'Average temperature per year', 'Hospital beds per 1000 people',
#        'Medical doctors per 1000 people', 'GDP/Capita', 'Population',
#        'Median age', 'Population aged 65 and over (%)', 'Date', 'Daily tests',
#        'Cases', 'Deaths'],
#       dtype='object')

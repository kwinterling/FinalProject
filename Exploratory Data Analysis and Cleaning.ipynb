# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
data_file = Path("Resources", "data", "data.csv")

covid_df = pd.read_csv(data_file)
covid_df.sample(10)
# Out:
#              Entity      Continent  Latitude  Longitude  \
# 13132       Iceland         Europe     64.96     -19.02
# 33066   Switzerland         Europe     46.82       8.23
# 21883      Mongolia           Asia     46.86     103.85
# 26469      Paraguay  South America    -23.44     -58.44
# 2291        Bahrain           Asia     25.93      50.64
# 17814        Kuwait           Asia     29.31      47.48
# 26082        Panama  North America      8.54     -80.78
# 31545  South Africa         Africa    -30.56      22.94
# 35302        Uganda         Africa      1.37      32.29
# 7044        Croatia         Europe     45.10      15.20
#
#        Average temperature per year  Hospital beds per 1000 people  \
# 13132                             2                           2.91
# 33066                             8                           4.53
# 21883                             2                           7.00
# 26469                            22                           1.30
# ...

# %%
covid_df.columns
# Out:
# Index(['Entity', 'Continent', 'Latitude', 'Longitude',
#        'Average temperature per year', 'Hospital beds per 1000 people',
#        'Medical doctors per 1000 people', 'GDP/Capita', 'Population',
#        'Median age', 'Population aged 65 and over (%)', 'Date', 'Daily tests',
#        'Cases', 'Deaths'],
#       dtype='object')

# %%
covid_df.dtypes
# Out:
# Entity                              object
# Continent                           object
# Latitude                           float64
# Longitude                          float64
# Average temperature per year         int64
# Hospital beds per 1000 people      float64
# Medical doctors per 1000 people    float64
# GDP/Capita                         float64
# Population                           int64
# Median age                           int64
# Population aged 65 and over (%)      int64
# Date                                object
# Daily tests                        float64
# Cases                              float64
# Deaths                             float64
# dtype: object

# %%
covid_df.drop(columns=['Average temperature per year', 'Continent'], axis=1)
# Out:
#          Entity  Latitude  Longitude  Hospital beds per 1000 people  \
# 0       Albania     41.15      20.17                           2.89
# 1       Albania     41.15      20.17                           2.89
# 2       Albania     41.15      20.17                           2.89
# 3       Albania     41.15      20.17                           2.89
# 4       Albania     41.15      20.17                           2.89
# ...         ...       ...        ...                            ...
# 38467  Zimbabwe    -19.02      29.15                           1.70
# 38468  Zimbabwe    -19.02      29.15                           1.70
# 38469  Zimbabwe    -19.02      29.15                           1.70
# 38470  Zimbabwe    -19.02      29.15                           1.70
# 38471  Zimbabwe    -19.02      29.15                           1.70
#
#        Medical doctors per 1000 people  GDP/Capita  Population  Median age  \
# ...

# %%
# Split Dataframe into two, one with demographic and population info, second with covid cases. 

description_df = covid_df['Entity', 'Latitude', 'Longitude', 'GDP/Capita', 'Population', 
                          'Median age', 'Population aged 65 and over (%)']
cases_df = covid_df['Entity', 'Date', 'Daily tests', 'Cases', 'Deaths']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Entity', 'Latitude', 'Longitude', 'GDP/Capita', 'Population', 'Median age', 'Population aged 65 and over (%)')
#
# ...

# %%
covid_df.Date = pd.to_datetime(covid_df.Date, format='%d%b%Y:%H:%M:%S.%f')

# %%
covid_df.dtypes
# Out:
# Entity                                     object
# Continent                                  object
# Latitude                                  float64
# Longitude                                 float64
# Average temperature per year                int64
# Hospital beds per 1000 people             float64
# Medical doctors per 1000 people           float64
# GDP/Capita                                float64
# Population                                  int64
# Median age                                  int64
# Population aged 65 and over (%)             int64
# Date                               datetime64[ns]
# Daily tests                               float64
# Cases                                     float64
# Deaths                                    float64
# dtype: object

# %%
covid_df.shape
# Out:
# (38472, 15)

# %%
df_no_tests = covid_df.drop('Daily tests', axis=1)
df_no_tests.dropna(inplace=True)
display(df_no_tests.sample(10))
print(df_no_tests.shape)
# Out:
#                      Entity Continent  Latitude  Longitude  \
# 16611                 Japan      Asia     36.20     138.25
# 18871             Lithuania    Europe     55.17      23.88
# 18592                 Libya    Africa     26.34      17.23
# 37960                Zambia    Africa    -13.13      27.85
# 36189  United Arab Emirates      Asia     23.42      53.85
# 11225                France    Europe     46.23       2.21
# 12839               Hungary    Europe     47.16      19.50
# 18746                 Libya    Africa     26.34      17.23
# 18168                Latvia    Europe     56.88      24.60
# 37675               Vietnam      Asia     14.06     108.28
#
#        Average temperature per year  Hospital beds per 1000 people  \
# 16611                            12                          13.05
# 18871                             7                           6.56
# 18592                            24                           3.70
# ...

# %%
df_with_tests = covid_df.dropna()
df_with_tests.shape
# Out:
# (28869, 15)

# %%
df_no_tests.groupby(['Entity','Date']).sum()
# Out:
#                      Latitude  Longitude  Average temperature per year  \
# Entity   Date
# Albania  2020-03-11     41.15      20.17                            14
#          2020-03-12     41.15      20.17                            14
#          2020-03-13     41.15      20.17                            14
#          2020-03-14     41.15      20.17                            14
#          2020-03-15     41.15      20.17                            14
# ...                       ...        ...                           ...
# Zimbabwe 2021-02-24    -19.02      29.15                            20
#          2021-02-25    -19.02      29.15                            20
#          2021-02-26    -19.02      29.15                            20
#          2021-02-27    -19.02      29.15                            20
#          2021-02-28    -19.02      29.15                            20
#
#                      Hospital beds per 1000 people  \
# Entity   Date
# ...

# %%
df_with_tests.groupby(['Entity','Date']).sum()
# Out:
#                      Latitude  Longitude  Average temperature per year  \
# Entity   Date
# Albania  2020-03-11     41.15      20.17                            14
#          2020-03-12     41.15      20.17                            14
#          2020-03-13     41.15      20.17                            14
#          2020-03-14     41.15      20.17                            14
#          2020-03-15     41.15      20.17                            14
# ...                       ...        ...                           ...
# Zimbabwe 2021-02-21    -19.02      29.15                            20
#          2021-02-22    -19.02      29.15                            20
#          2021-02-23    -19.02      29.15                            20
#          2021-02-24    -19.02      29.15                            20
#          2021-02-25    -19.02      29.15                            20
#
#                      Hospital beds per 1000 people  \
# Entity   Date
# ...

# %%
df_no_tests.groupby(['Entity','Date']).Deaths.sum()
# Out:
# Entity    Date
# Albania   2020-03-11       1.0
#           2020-03-12       1.0
#           2020-03-13       1.0
#           2020-03-14       1.0
#           2020-03-15       1.0
#                          ...
# Zimbabwe  2021-02-24    1456.0
#           2021-02-25    1458.0
#           2021-02-26    1463.0
#           2021-02-27    1463.0
#           2021-02-28    1463.0
# Name: Deaths, Length: 34862, dtype: float64

# %%
[df_with_tests["Date"].min(), df_with_tests["Date"].max()]
# Out:
# [Timestamp('2020-02-13 00:00:00'), Timestamp('2021-02-26 00:00:00')]

# %%
df_with_tests.loc[df_with_tests["Entity"] == 'Albania'].plot(x="Date", y="Deaths")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_no_tests.loc[df_no_tests["Entity"] == 'Albania'].plot(x="Date", y="Deaths")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_no_tests.loc[df_no_tests["Entity"] == 'Albania'].plot(x="Medical doctors per 1000 people", y="Deaths")
# Out:
# <AxesSubplot:xlabel='Medical doctors per 1000 people'>

# %%
import pandas as pd

# %%
smokers = pd.read_csv('C:\\Users\kelle\Desktop\Bootcamp\FinalProject\smoker_data\Resources\\train_dataset.csv')
smokers.columns
# Out:
# Index(['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)',
#        'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic',
#        'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride',
#        'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'serum creatinine', 'AST',
#        'ALT', 'Gtp', 'dental caries', 'smoking'],
#       dtype='object')

# %%
smokers = smokers.reset_index()
smokers = smokers.rename(columns={'index':'id'})
smokers.head()
# Out:
#    id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0   35         170          85       97.0             0.9
# 1   1   20         175         110      110.0             0.7
# 2   2   45         155          65       86.0             0.9
# 3   3   45         165          80       94.0             0.8
# 4   4   20         165          60       81.0             1.5
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  HDL  LDL  \
# 0              0.9              1               1       118  ...   70  142
# 1              0.9              1               1       119  ...   71  114
# 2              0.9              1               1       110  ...   57  112
# 3              0.7              1               1       158  ...   46   91
# 4              0.1              1               1       109  ...   47   92
#
#    hemoglobin  Urine protein  serum creatinine   AST   ALT  Gtp  \
# 0        19.8              1               1.0    61   115  125
# ...

# %%
smokers.to_csv('C:\\Users\kelle\Desktop\Bootcamp\FinalProject\smoker_data\Resources\\smokers_upload.csv')
